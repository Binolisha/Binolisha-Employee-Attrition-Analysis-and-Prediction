# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#loading Data
employee=pd.read_excel("Employee-Attrition.xlsx")
employee.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
#to view all the columns in the dataframe
pd.set_option('display.max_column',None)

# %%
employee.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
employee["YearsWithCurrManager"].unique()
# Out:
# array([ 5,  7,  0,  2,  6,  8,  3, 11, 17,  1,  4, 12,  9, 10, 15, 13, 16,
#        14], dtype=int64)

# %%
#checking null values
employee.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#information about the data
employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
#shape of the data
employee.shape
# Out:
# (1470, 35)

# %%
#describing the data
employee.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#checking duplicates
employee.duplicated().value_counts()
# Out:
# False    1470
# Name: count, dtype: int64

# %%
#removing duplicates
employee.drop_duplicates(inplace=True)

# %%
#target variable
plt.figure(figsize=(15,5))
plt.rc("font",size=14)
sns.countplot(data=employee,y="PerformanceRating")
plt.show()

# %%
categorical_cols = employee.select_dtypes(include=['object', 'category']).columns

# Set plot style
plt.rc("font", size=14)
plt.figure(figsize=(15, 5 * len(categorical_cols)))  # Adjust figure size dynamically

# Loop through each categorical column
for i, col in enumerate(categorical_cols, 1):
    plt.subplot(len(categorical_cols), 1, i)  # Create subplots
    sns.countplot(data=employee, hue="PerformanceRating", x=col)
    plt.title(f"Distribution of {col} by Performance Rating")
    plt.xticks(rotation=45)  # Rotate x-axis labels for readability

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %% [markdown]
# 1.Travelling rarely have high performance rating
# 2.reducing overtime duty increases the performance rating

# %%
numeric_cols = employee.select_dtypes(include=['number']).columns.difference(['PerformanceRating',"MonthlyRate","DailyRate","EmployeeNumber","Hourlyrate","MonthlyIncome","MonthlyRate"])
# Set plot style
plt.rc("font", size=14)
plt.figure(figsize=(15, 5 * len(numeric_cols)))  # Adjust figure size dynamically

# Loop through each categorical column
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(len(numeric_cols), 1, i)  # Create subplots
    sns.countplot(data=employee, hue="PerformanceRating", x=col)
    plt.title(f"Distribution of {col} by Performance Rating")
    plt.xticks(rotation=45)  # Rotate x-axis labels for readability

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %% [markdown]
# 1.age between 26 to 46 have high performace
# 2.person with less diatance of home give high performance
# 3.increase in hike percent increases the performance
# 4.worklife balance is essential
# 5.years at comapany
# 6.years in current role
# years since last promotion

# %%
plt.figure(figsize=(15,5))
plt.rc("font",size=14)
sns.histplot(data=employee,hue="PerformanceRating",x='MonthlyIncome')
plt.show()

# %%
sns.distplot(employee["MonthlyIncome"])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_26872\4044986251.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(employee["MonthlyIncome"])
# <Axes: xlabel='MonthlyIncome', ylabel='Density'>

# %%
plt.figure(figsize=(20,16))
numeric_employee = employee.select_dtypes(include=['number'])  
sns.heatmap(numeric_employee.corr(), annot=True, cmap="coolwarm")
plt.show()

# %%
performance_rating=employee

# %%
#target variable
performance_rating["PerformanceRating"]=performance_rating["PerformanceRating"].replace({3:0,4:1})
performance_rating
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
#binary variable
performance_rating["OverTime"]=performance_rating["OverTime"].map({"No":0,"Yes":1})
performance_rating["Gender"]=performance_rating["Gender"].map({"Male":0,"Female":1})

# %%
#encode categorical column
from sklearn.preprocessing import LabelEncoder
col=["BusinessTravel","Department","EducationField","JobRole"]
label_encoder={}
for column in col:
    label_encoder[column]=LabelEncoder()
    performance_rating[column]=label_encoder[column].fit_transform(performance_rating[column])

# %%
performance_rating.head()
# Out:
#    Age Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41       Yes               2       1102           2                 1
# 1   49        No               1        279           1                 8
# 2   37       Yes               2       1373           1                 2
# 3   33        No               1       1392           1                 3
# 4   27        No               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0          2               1              1               1
# 1          1               1              1               2
# 2          2               4              1               4
# 3          4               1              1               5
# 4          1               3              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       1          94               3         2
# ...

# %%
#split into feature and target
X=performance_rating.drop(["Attrition","DailyRate","Education","EducationField","EmployeeCount","EmployeeNumber","HourlyRate","JobInvolvement","JobLevel","MaritalStatus","MonthlyRate","NumCompaniesWorked","Over18","PerformanceRating","RelationshipSatisfaction","StandardHours","StockOptionLevel",
"TrainingTimesLastYear"],axis=1)
y=performance_rating["PerformanceRating"].values

# %%
#resampling
from collections import Counter 
from imblearn.over_sampling import RandomOverSampler
print(Counter(y))
rus=RandomOverSampler(random_state=42)
X_over,y_over=rus.fit_resample(X,y)
print(Counter(y_over))
# Out:
# Counter({0: 1244, 1: 226})
# Counter({0: 1244, 1: 1244})

# %%
#splitting data into train and test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_over,y_over,test_size=0.3,random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1741, 17)
# (747, 17)
# (1741,)
# (747,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score

# Train Logistic Regression
lr_model = LogisticRegression(max_iter=10000, random_state=0)
lr_model.fit(X_train, y_train)
lr_preds = lr_model.predict(X_test)

# Train Support Vector Classification
svc_model = SVC(kernel='rbf')   
svc_model.fit(X_train, y_train) 
svc_preds = svc_model.predict(X_test)

# Train Decision Tree Classification
dt_model = DecisionTreeClassifier(random_state=0,max_depth=2)
dt_model.fit(X_train, y_train)
dt_preds = dt_model.predict(X_test)

# Train Random Forest
rf_model = RandomForestClassifier(max_depth=2,n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
rf_preds = rf_model.predict(X_test)

# Train KNN
knn_model= KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X_train, y_train)
knn_preds = knn_model.predict(X_test)

# Train XGBoost
xgb_model = XGBClassifier()
xgb_model.fit(X_train, y_train)
xgb_preds = xgb_model.predict(X_test)

# Train naive bayes
nb_model = GaussianNB()
nb_model.fit(X_train, y_train)
nb_preds = nb_model.predict(X_test)

def evaluate_model(name, y_true, y_pred):
    print(f"Performance of {name}:")
    print(f"Accuracy: {accuracy_score(y_true, y_pred):.2f}")
    print(f"Precision: {precision_score(y_true, y_pred):.2f}")
    print(f"Recall: {recall_score(y_true, y_pred):.2f}")
    print(f"F1-score: {f1_score(y_true, y_pred):.2f}")
    print("-" * 30)

evaluate_model("Logistic Regression", y_test, lr_preds)
evaluate_model("Support Vector Classification", y_test, svc_preds)
evaluate_model("Decision Tree Classification", y_test, dt_preds)
evaluate_model("Random Forest Classification", y_test, rf_preds)
evaluate_model("K-Nearest Neighbour Classification", y_test, rf_preds)
evaluate_model("XGBoost Classification", y_test, xgb_preds)
evaluate_model("Naive Bayes Classification", y_test, nb_preds)
# Out:
# Performance of Logistic Regression:
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# F1-score: 1.00
# ------------------------------
# Performance of Support Vector Classification:
# Accuracy: 0.52
# Precision: 0.51
# Recall: 0.46
# F1-score: 0.48
# ------------------------------
# Performance of Decision Tree Classification:
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# F1-score: 1.00
# ------------------------------
# Performance of Random Forest Classification:
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# F1-score: 1.00
# ------------------------------
# Performance of K-Nearest Neighbour Classification:
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# F1-score: 1.00
# ------------------------------
# Performance of XGBoost Classification:
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# F1-score: 1.00
# ------------------------------
# Performance of Naive Bayes Classification:
# Accuracy: 0.97
# Precision: 0.94
# Recall: 1.00
# F1-score: 0.97
# ...

# %%
from sklearn.metrics import roc_auc_score

y_probs = rf_model.predict_proba(X_test)[:, 1]   
roc_auc = roc_auc_score(y_test, y_probs)

print(f"ROC-AUC Score: {roc_auc:.2f}")
# Out:
# ROC-AUC Score: 1.00

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_pred= rf_model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
# Plot Confusion Matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues")
plt.show()

# %%
import time

start_time = time.time() # Start the timer
rf_model = RandomForestClassifier(n_estimators=100, random_state=42) # Train the XGBoost model
rf_model.fit(X_train, y_train)
end_time = time.time() # End the timer
training_time = end_time - start_time
print(f"Training Time: {training_time:.2f} seconds")
# Out:
# Training Time: 0.68 seconds

# %%
import os
model_path=os.path.abspath("performancerating_prediction_model.pkl")
print(f"Model saved at: {model_path}")
# Out:
# Model saved at: C:\Users\DELL\performancerating_prediction_model.pkl
