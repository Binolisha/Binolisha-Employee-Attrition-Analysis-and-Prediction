# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#loading Data
employee=pd.read_excel("Employee-Attrition.xlsx")
employee.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
#to view all the columns in the dataframe
pd.set_option('display.max_column',None)

# %%
employee.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
employee["PerformanceRating"].unique()
# Out:
# array([3, 4], dtype=int64)

# %%
sns.distplot(employee["MonthlyIncome"])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_25164\4044986251.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(employee["MonthlyIncome"])
# <Axes: xlabel='MonthlyIncome', ylabel='Density'>

# %%
#checking null values
employee.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#information about the data
employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
#shape of the data
employee.shape
# Out:
# (1470, 35)

# %%
#describing the data
employee.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#checking duplicates
employee.duplicated().value_counts()
# Out:
# False    1470
# Name: count, dtype: int64

# %%
#removing duplicates
employee.drop_duplicates(inplace=True)

# %%
#target variable
plt.figure(figsize=(15,5))
plt.rc("font",size=14)
sns.countplot(data=employee,y="Attrition")
plt.show()

# %% [markdown]
# The data is imbanced.it should be balanced using SMOTE

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
#department vs attrition
plt.figure(figsize=(12,5))
sns.countplot(data=employee,x="Department",hue="Attrition",palette="hot")
plt.title("Department Vs Attrition")
# Out:
# Text(0.5, 1.0, 'Department Vs Attrition')

# %%
#education vs attrition
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="EducationField",hue="Attrition",palette="hot")
plt.title("EducationField Vs Attrition")
# Out:
# Text(0.5, 1.0, 'EducationField Vs Attrition')

# %%
#Jobrole vs attrition
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="JobRole",hue="Attrition",palette="hot")
plt.title("JobRole Vs Attrition")
plt.xticks(rotation=45)
plt.show()

# %%
#Gender vs attrition
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="Gender",hue="Attrition",palette="hot")
plt.title("Gender Vs Attrition")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.distplot(employee["Age"],hist=False)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_28144\1117560406.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(employee["Age"],hist=False)

# %%
#Education Vs Attrition
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="Education",hue="Attrition",palette="hot")
plt.title("Education Vs Attrition")
plt.show()

# %%
#Business trvael
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="BusinessTravel",hue="Attrition",palette="hot")
plt.title("Business Travel Vs Attrition")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="DistanceFromHome",hue="Attrition",palette="hot")
plt.title("DistanceFromHome Vs Attrition")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="EnvironmentSatisfaction",hue="Attrition",palette="hot")
plt.title("EnvironmentSatisfaction Vs Attrition")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="JobInvolvement",hue="Attrition",palette="hot")
plt.title("Job Involvement Vs Attrition")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="JobLevel",hue="Attrition",palette="hot")
plt.title("Job Level Vs Attrition")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="JobSatisfaction",hue="Attrition",palette="hot")
plt.title("JobSatisfaction Vs Attrition")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="MaritalStatus",hue="Attrition",palette="hot")
plt.title("MaritalStatus Vs Attrition")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="NumCompaniesWorked",hue="Attrition",palette="hot")
plt.title("NumCompaniesWorked Vs Attrition")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="Over18",hue="Attrition",palette="hot")
plt.title("Over18 Vs Attrition")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="PerformanceRating",hue="Attrition",palette="hot")
plt.title("Performance Rating Vs Attrition")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="RelationshipSatisfaction",hue="Attrition",palette="hot")
plt.title("Relationship Satisfaction Vs Attrition")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="StandardHours",hue="Attrition",palette="hot")
plt.title("Standard HoursVs Attrition")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="TotalWorkingYears",hue="Attrition",palette="hot")
plt.title("Total Working Years Vs Attrition")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="TrainingTimesLastYear",hue="Attrition",palette="hot")
plt.title("Training Times Last Year Vs Attrition")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="WorkLifeBalance",hue="Attrition",palette="hot")
plt.title("Work Life Balance Vs Attrition")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="YearsAtCompany",hue="Attrition",palette="hot")
plt.title("Years At Company Vs Attrition")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="YearsInCurrentRole",hue="Attrition",palette="hot")
plt.title("Years In Current RoleVs Attrition")
plt.show()
#YearsInCurrentRole	YearsSinceLastPromotion	YearsWithCurrManager

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="YearsSinceLastPromotion",hue="Attrition",palette="hot")
plt.title("Years Since Last Promotion Vs Attrition")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="YearsWithCurrManager",hue="Attrition",palette="hot")
plt.title("Years With Curr Manager Vs Attrition")
plt.show()

# %%
#employee["PercentSalaryHike"].unique()
plt.figure(figsize=(15,5))
sns.countplot(data=employee,x="PercentSalaryHike",hue="Attrition",palette="hot")
plt.title("Percent Salary Hike Vs Attrition")
plt.show()

# %%
attrition_prediction=employee
attrition_prediction
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
#target variable
attrition_prediction["Attrition"]=attrition_prediction["Attrition"].replace({"No":0,"Yes":1})
attrition_prediction
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_28144\1545182141.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   attrition_prediction["Attrition"]=attrition_prediction["Attrition"].replace({"No":0,"Yes":1})
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# ...

# %%
#binary variable
attrition_prediction["OverTime"]=attrition_prediction["OverTime"].map({"No":0,"Yes":1})
attrition_prediction["Gender"]=attrition_prediction["Gender"].map({"Male":0,"Female":1})

# %%
#encode categorical column
from sklearn.preprocessing import LabelEncoder
col=["BusinessTravel","Department","EducationField","JobRole","MaritalStatus"]
label_encoder={}
for column in col:
    label_encoder[column]=LabelEncoder()
    attrition_prediction[column]=label_encoder[column].fit_transform(attrition_prediction[column])

# %%
attrition_prediction.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0          2               1              1               1
# 1          1               1              1               2
# 2          2               4              1               4
# 3          4               1              1               5
# 4          1               3              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       1          94               3         2
# ...

# %%
#split into feature and target
X=attrition_prediction.drop(["Attrition","DailyRate","EmployeeCount","EmployeeNumber","HourlyRate","MonthlyRate","Over18","RelationshipSatisfaction","StandardHours","StockOptionLevel",
"TrainingTimesLastYear","WorkLifeBalance","YearsAtCompany","YearsInCurrentRole","YearsSinceLastPromotion","YearsWithCurrManager"],axis=1)
y=attrition_prediction["Attrition"].values

# %%
#resampling
from collections import Counter 
from imblearn.over_sampling import RandomOverSampler
print(Counter(y))
rus=RandomOverSampler(random_state=42)
X_over,y_over=rus.fit_resample(X,y)
print(Counter(y_over))
# Out:
# Counter({0: 1233, 1: 237})
# Counter({1: 1233, 0: 1233})

# %%
#splitting data into train and test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_over,y_over,test_size=0.3,random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1726, 19)
# (740, 19)
# (1726,)
# (740,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score

# Train Logistic Regression
lr_model = LogisticRegression(max_iter=10000, random_state=0)
lr_model.fit(X_train, y_train)
lr_preds = lr_model.predict(X_test)

# Train Support Vector Classification
svc_model = SVC(kernel='rbf')   
svc_model.fit(X_train, y_train) 
svc_preds = svc_model.predict(X_test)

# Train Decision Tree Classification
dt_model = DecisionTreeClassifier(random_state=0,max_depth=2)
dt_model.fit(X_train, y_train)
dt_preds = dt_model.predict(X_test)

# Train Random Forest
rf_model = RandomForestClassifier(random_state=0,max_depth=2)
rf_model.fit(X_train, y_train)
rf_preds = rf_model.predict(X_test)

# Train KNN
knn_model= KNeighborsClassifier()
knn_model.fit(X_train, y_train)
knn_preds = knn_model.predict(X_test)

# Train XGBoost
xgb_model = XGBClassifier()
xgb_model.fit(X_train, y_train)
xgb_preds = xgb_model.predict(X_test)

# Train naive bayes
nb_model = GaussianNB()
nb_model.fit(X_train, y_train)
nb_preds = nb_model.predict(X_test)

def evaluate_model(name, y_true, y_pred):
    print(f"Performance of {name}:")
    print(f"Accuracy: {accuracy_score(y_true, y_pred):.2f}")
    print(f"Precision: {precision_score(y_true, y_pred):.2f}")
    print(f"Recall: {recall_score(y_true, y_pred):.2f}")
    print(f"F1-score: {f1_score(y_true, y_pred):.2f}")
    print("-" * 30)

evaluate_model("Logistic Regression", y_test, lr_preds)
evaluate_model("Support Vector Classification", y_test, svc_preds)
evaluate_model("Decision Tree Classification", y_test, dt_preds)
evaluate_model("Random Forest Classification", y_test, rf_preds)
evaluate_model("K-Nearest Neighbour Classification", y_test, rf_preds)
evaluate_model("XGBoost Classification", y_test, xgb_preds)
evaluate_model("Naive Bayes Classification", y_test, nb_preds)
# Out:
# Performance of Logistic Regression:
# Accuracy: 0.71
# Precision: 0.71
# Recall: 0.73
# F1-score: 0.72
# ------------------------------
# Performance of Support Vector Classification:
# Accuracy: 0.63
# Precision: 0.66
# Recall: 0.53
# F1-score: 0.59
# ------------------------------
# Performance of Decision Tree Classification:
# Accuracy: 0.69
# Precision: 0.71
# Recall: 0.65
# F1-score: 0.68
# ------------------------------
# Performance of Random Forest Classification:
# Accuracy: 0.71
# Precision: 0.76
# Recall: 0.61
# F1-score: 0.68
# ------------------------------
# Performance of K-Nearest Neighbour Classification:
# Accuracy: 0.71
# Precision: 0.76
# Recall: 0.61
# F1-score: 0.68
# ------------------------------
# Performance of XGBoost Classification:
# Accuracy: 0.94
# Precision: 0.91
# Recall: 0.98
# F1-score: 0.94
# ------------------------------
# Performance of Naive Bayes Classification:
# Accuracy: 0.67
# Precision: 0.65
# Recall: 0.76
# F1-score: 0.70
# ...

# %%
from sklearn.metrics import roc_auc_score

y_probs = xgb_model.predict_proba(X_test)[:, 1]   
roc_auc = roc_auc_score(y_test, y_probs)

print(f"ROC-AUC Score: {roc_auc:.2f}")
# Out:
# ROC-AUC Score: 0.98

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_pred= xgb_model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
# Plot Confusion Matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues")
plt.show()

# %%
import time
import xgboost as xgb

start_time = time.time() # Start the timer
xgb_model = xgb.XGBClassifier() # Train the XGBoost model
xgb_model.fit(X_train, y_train)
end_time = time.time() # End the timer
training_time = end_time - start_time
print(f"Training Time: {training_time:.2f} seconds")
# Out:
# Training Time: 0.09 seconds

# %%
import os
model_path=os.path.abspath("attrition_prediction_model.pkl")
print(f"Model saved at: {model_path}")
# Out:
# Model saved at: C:\Users\DELL\attrition_prediction_model.pkl
